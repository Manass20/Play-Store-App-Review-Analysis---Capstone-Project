# %% [markdown]
# <a href="https://colab.research.google.com/github/Manass20/Play-Store-App-Review-Analysis---Capstone-Project/blob/main/Manas_Ranjan_Play_Store_App_Review_Analysis_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> The Play Store apps data has enormous potential to drive app-making businesses to success. Actionable insights can be drawn for developers to work on and capture the Android market. </b>
#
# ## <b> Each app (row) has values for catergory, rating, size, and more. Another dataset contains customer reviews of the android apps.</b>
#
# ## <b> Explore and analyze the data to discover key factors responsible for app engagement and success. </b>

# %% [markdown]
# ##**Introduction**
#
# Play Store is a platform for browsing and downloading Android applications provided by Google. It is an official app store for certified Android applications developed using the Android Software Development Kit. It includes both free as well as paid apps.
#  Our study used two datasets, one dataset consisted of information on play store apps, their ratings, and the basic information about the apps, and another was a user review dataset, which provided users' opinions of the apps.

# %% [markdown]
# # **FIRST STEP :-**

# %% [markdown]
# # **IMPORTING THE NECESSARY LIBRARIES**

# %%
import pandas as pd  # pandas library

import numpy as np   # numpy library

import matplotlib  

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %% [markdown]
# ## **IMPORTING THE DATASET'S INTO OUR COLLAB NOTEBOOK**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## **Below are the libraries that are used in order to perform EDA (Exploratory data analysis):**

# %% [markdown]
# *   Loading the data into the pandas data frame is certainly one of the most important steps in EDA, as we can see that the value from the data set is comma-separated

# %%
path='/content/drive/MyDrive/Colab Notebooks/AlmaBetter/PROJECTS/EDA/PLAY STORE/Play Store Data.csv'
store_df= pd.read_csv(path)
path_userRatings='/content/drive/MyDrive/Colab Notebooks/AlmaBetter/PROJECTS/EDA/PLAY STORE/User Reviews.csv'
ratings_df= pd.read_csv(path_userRatings)

# %% [markdown]
# ## **SECOND STEP:-**

# %% [markdown]
# ## **DATA EXPLORATION**

# %%
#Displaying the top 5 rows
store_df.head(5)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
#Displaying the bottom 10 rows
store_df.tail(10)
# Out:
#                                                  App             Category  \
# 10831                       payermonstationnement.fr  MAPS_AND_NAVIGATION
# 10832                                       FR Tides              WEATHER
# 10833                                    Chemin (fr)  BOOKS_AND_REFERENCE
# 10834                                  FR Calculator               FAMILY
# 10835                                       FR Forms             BUSINESS
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10831     NaN      38                9.8M       5,000+  Free     0
# 10832     3.8    1195                582k     100,000+  Free     0
# 10833     4.8      44                619k       1,000+  Free     0
# 10834     4.0       7                2.6M         500+  Free     0
# 10835     NaN       0                9.6M          10+  Free     0
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres        Last Updated  \
# 10831       Everyone  Maps & Navigation       June 13, 2018
# 10832       Everyone            Weather   February 16, 2014
# 10833       Everyone  Books & Reference      March 23, 2014
# 10834       Everyone          Education       June 18, 2017
# 10835       Everyone           Business  September 29, 2016
# 10836       Everyone          Education       July 25, 2017
# 10837       Everyone          Education        July 6, 2018
# 10838       Everyone            Medical    January 20, 2017
# 10839     Mature 17+  Books & Reference    January 19, 2015
# 10840       Everyone          Lifestyle       July 25, 2018
#
#               Current Ver         Android Ver
# 10831           2.0.148.0          4.0 and up
# 10832                 6.0          2.1 and up
# 10833                 0.8          2.2 and up
# 10834               1.0.0          4.1 and up
# 10835               1.1.5          4.0 and up
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device

# %%
#Displaying the first 10 rows
ratings_df.head(10)
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
# 5  10 Best Foods for You                                           Best way
# 6  10 Best Foods for You                                            Amazing
# 7  10 Best Foods for You                                                NaN
# 8  10 Best Foods for You                               Looking forward app,
# 9  10 Best Foods for You              It helpful site ! It help foods get !
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000
# 5  Positive                1.00                0.300000
# 6  Positive                0.60                0.900000
# 7       NaN                 NaN                     NaN
# 8   Neutral                0.00                0.000000
# 9   Neutral                0.00                0.000000

# %%
#Displaying the bottom 10 rows
ratings_df.tail(10)
# Out:
#                                App Translated_Review Sentiment  \
# 64285  Houzz Interior Design Ideas               NaN       NaN
# 64286  Houzz Interior Design Ideas               NaN       NaN
# 64287  Houzz Interior Design Ideas               NaN       NaN
# 64288  Houzz Interior Design Ideas               NaN       NaN
# 64289  Houzz Interior Design Ideas               NaN       NaN
# 64290  Houzz Interior Design Ideas               NaN       NaN
# 64291  Houzz Interior Design Ideas               NaN       NaN
# 64292  Houzz Interior Design Ideas               NaN       NaN
# 64293  Houzz Interior Design Ideas               NaN       NaN
# 64294  Houzz Interior Design Ideas               NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 64285                 NaN                     NaN
# 64286                 NaN                     NaN
# 64287                 NaN                     NaN
# 64288                 NaN                     NaN
# 64289                 NaN                     NaN
# 64290                 NaN                     NaN
# 64291                 NaN                     NaN
# 64292                 NaN                     NaN
# 64293                 NaN                     NaN
# 64294                 NaN                     NaN

# %%
# Checking the data type
store_df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
# Checking the data type
ratings_df.dtypes
# Out:
# App                        object
# Translated_Review          object
# Sentiment                  object
# Sentiment_Polarity        float64
# Sentiment_Subjectivity    float64
# dtype: object

# %%
# Checking the number ofrows andd column
store_df.shape
# Out:
# (10841, 13)

# %%
# Checking the number ofrows andd column
ratings_df.shape
# Out:
# (64295, 5)

# %% [markdown]
# # **By diagnosing the Play Store DF & User Ratings DF, we get to know that:**
#
# ### IN Play Store DF
# 1.   There are 13 columns of properties with 10841 rows of data.
# 2.   Column 'Reviews', 'Size', 'Installs' and 'Price' are in the type of 'object'.
# 3.   Values of column 'Size' are strings representing size in 'M' as Megabytes, 'k' as kilobytes and also 'Varies with devices'.
# 4.   Values of column 'Installs' are strings representing install amount with symbols such as ',' and '+'.
# 5.   Values of column 'Price' are strings representing price with symbol '$'.
# 6.   There is only one float64 type column which is 'Rating'.
#
# ### IN User Ratings DF
#
# 1.  There are 5 columns of properties with 64295 rows of data.
# 2.  Column App,Translated_Review,Sentiment are in the type of 'object'.
# 3.  Column Sentiment_Polarity,Sentiment_Subjectivity are in the type of float64

# %% [markdown]
# ## **THIRD STEP:-**
# ## **DATA CLEANING**

# %% [markdown]
# In data cleaning we will check for:
#
#
# 1.   Null values/NaN values
# 2.   Duplicates
# 3.   Outlier Detection

# %%
# 1. CLEAN THE REVIEWS DATA AND CHANGE THE TYPE FROM 'OBJECT' TO 'FLOAT'

reviews = [i for i in store_df['Reviews']]

def clean_ratings(rating_list):

  """
  An 'M has been found while changing the type,
  this function will replace the 'M' with million
  """

  cleaned_data = []
  for review in rating_list:

    if 'M' in review:
      review = review.replace('M', '')
      review = float(review) * 1000000    # 1 M = 10,00,000
    cleaned_data.append(review)
    
  return cleaned_data

# %%
store_df['Reviews'] = clean_ratings(reviews)
store_df['Reviews'] = store_df['Reviews'].astype(float)

# %%
# FOUND A ROW WITH 1000+ IN SIZE COLUMN
# REMOVING IT AS WE ARE UNCERTAIN ABOUT IT

index = store_df[store_df['Size'] == '1,000+'].index
store_df.drop(axis = 0, inplace = True, index = index)

# %%
# 2. CLEAN SIZE DATA COLUMN AND CHANGE ITS TYPE FROM 'OBJECT' TO 'FLOAT'

sizes = [i for i in store_df['Size']]

def clean_size(size_list):

  """
  As sizes are repesented in 'M' or 'K', we
      remove 'M' and convert 'K' into 'M'
  """

  cleaned_data = []
  for size in size_list:

    if 'M' in size:
      size = size.replace('M', '')
      size = float(size)

    elif 'k' in size:
      size = size.replace('k', '')
      size = float(size)
      size = size / 1024    # 1 MB = 1024 KB

    else:
      size = float(0)       # REPRESENTING 'VARIES WITH DEVICE' WITH VALUE 0
    cleaned_data.append(size)
    
  return cleaned_data

# %%
store_df['Size'] = clean_size(sizes)
store_df['Size'] = store_df['Size'].astype(float)

# %%
store_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews  Size     Installs  Type Price Content Rating  \
# 0     159.0  19.0      10,000+  Free     0       Everyone
# 1     967.0  14.0     500,000+  Free     0       Everyone
# 2   87510.0   8.7   5,000,000+  Free     0       Everyone
# 3  215644.0  25.0  50,000,000+  Free     0           Teen
# 4     967.0   2.8     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
store_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  float64
#  4   Size            10840 non-null  float64
#  5   Installs        10840 non-null  object
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(3), object(10)
# memory usage: 1.2+ MB

# %%
# 3. CLEAN THE INSTALLS DATA AND CHANGE THE TYPE FROM 'OBJECT' TO 'FLOAT'

installs = [i for i in store_df['Installs']]

def clean_install(install_list):
  """
  This function removes the + and , from the data.
  There is one row where installs is 'Free'. Since there is only one,
  so, we make it 0.
  """
  
  clean_data = []
  for install in install_list:

    if '+' in install:
      install = install.replace('+', '')  # REMOVE +

    if ',' in install:
      install = install.replace(',', '')  # REMOVE ,
    
    install = int(install)
    clean_data.append(install)

  return clean_data

# %%
store_df['Installs'] = clean_install(installs)
store_df['Installs'] = store_df['Installs'].astype(float)

# %%
# 4. CLEAN THE PRICE DATA AND CHANGE THE TYPE FROM 'OBJECT' TO 'FLOAT'

prices = [i for i in store_df['Price']]

def clean_prices(price_list):
  """
  This function removes the '$' sign from the data.
  There is one row of price column with data as everyone.
  Making it free or 0.
  """
  clean_data = []
  for price in price_list:

    if '$' in price:
      price = price.replace('$', '')

    clean_data.append(price)
  
  return clean_data

# %%
store_df['Price'] = clean_prices(prices)
store_df['Price'] = store_df['Price'].astype(float)

# %%
store_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  float64
#  4   Size            10840 non-null  float64
#  5   Installs        10840 non-null  float64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(5), object(8)
# memory usage: 1.2+ MB

# %%
# CHECKING FOR NULL VALUES

store_df.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %% [markdown]
# So, there are 1474 null values under 'Rating' column. So, we are going to replace with median of overall rating values.

# %%
def replace_with_median(series):
  """
  Takes a series and replace the null values with median
  """
  return series.fillna(series.fillna(series.median()))

# %%
store_df['Rating'] = store_df['Rating'].transform(replace_with_median)
store_df['Rating'] = store_df['Rating'].astype(float)

# %%
# REMOVE THE RECORD WHERE 'TYPE' IS HAVING NULL VALUE

index = store_df[store_df['Type'].isna()].index
store_df.drop(axis = 0, inplace = True, index = index)

# %%
# CHECKING FOR NULL VALUES AGAIN

store_df.isna().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       2
# dtype: int64

# %%
# FILLING THE NULL VALUES OF CURRENT VERSION WITH 1.0

store_df['Current Ver'] = store_df['Current Ver'].fillna(1.0)

# %%
# FILLING THE NULL VALUES OF ANDROID VERSION WITH PREVIOUS DATA

store_df['Android Ver'] = store_df['Android Ver'].fillna(method = 'pad')

# %%
# CHECKING FOR NULL VALUES AGAIN

store_df.isna().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
# DROPPING THE DUPLICATE ROWS BASED ON APPS

store_df.drop_duplicates(subset = ['App'], inplace=True)

# %%
# CHECK ON STATISTICAL INFORMATION OF THE DATAFRAME

store_df.describe()
# Out:
#             Rating       Reviews         Size      Installs        Price
# count  9658.000000  9.658000e+03  9658.000000  9.658000e+03  9658.000000
# mean      4.192431  2.166150e+05    17.805940  7.778312e+06     1.099413
# std       0.496422  1.831413e+06    21.495867  5.376100e+07    16.853021
# min       1.000000  0.000000e+00     0.000000  0.000000e+00     0.000000
# 25%       4.000000  2.500000e+01     2.900000  1.000000e+03     0.000000
# 50%       4.300000  9.670000e+02     9.100000  1.000000e+05     0.000000
# 75%       4.500000  2.940800e+04    25.000000  1.000000e+06     0.000000
# max       5.000000  7.815831e+07   100.000000  1.000000e+09   400.000000

# %% [markdown]
# *  Half of the apps are less than 10 MB.
# *  Maximum size of the available app in this data is 100 MB.

# %%
# CHECKING FOR THE USER REVIEW DATAFRAME

review_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/AlmaBetter/PROJECTS/EDA/PLAY STORE/User Reviews.csv')
review_df.head(10)
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
# 5  10 Best Foods for You                                           Best way
# 6  10 Best Foods for You                                            Amazing
# 7  10 Best Foods for You                                                NaN
# 8  10 Best Foods for You                               Looking forward app,
# 9  10 Best Foods for You              It helpful site ! It help foods get !
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000
# 5  Positive                1.00                0.300000
# 6  Positive                0.60                0.900000
# 7       NaN                 NaN                     NaN
# 8   Neutral                0.00                0.000000
# 9   Neutral                0.00                0.000000

# %%
# CHECKING FOR DATA TYPES

review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %%
# CHECKING FOR THE NULL VALUES

review_df.isna().sum()
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
# REPLACING THE NULL VALUES OF TRANSLATED REVIEW WITH ITS PREVIOUS ONE

review_df['Translated_Review'] = review_df['Translated_Review'].fillna(method = 'pad')

# %%
# REPLACING THE NULL VALUES OF SENTIMENT WITH ITS PREVIOUS ONE

review_df['Sentiment'] = review_df['Sentiment'].fillna(method = 'pad')

# %%
# REPLACING THE NULL VALUES OF SENTIMENT POLARITY AND SENTIMENT SUBJECTIVITY WITH ITS MEDIAN

review_df['Sentiment_Polarity'] = review_df['Sentiment_Polarity'].transform(replace_with_median)
review_df['Sentiment_Subjectivity'] = review_df['Sentiment_Subjectivity'].transform(replace_with_median)

# %%
# CHECKING FOR THE NULL VALUES AGAIN

review_df.isna().sum()
# Out:
# App                       0
# Translated_Review         0
# Sentiment                 0
# Sentiment_Polarity        0
# Sentiment_Subjectivity    0
# dtype: int64

# %% [markdown]
# #Exaploratory Analysis and Visualization

# %% [markdown]
# ##Category

# %%
# NUMBER OF APPS IN EACH CATEGORY

sns.set_style('darkgrid')
plt.figure(figsize = (10, 5))
sns.countplot(x = 'Category', data = store_df)

plt.title('Number of Apps in each Category', size = 20)
plt.xticks(rotation = 90)
plt.xlabel('<-----App Category ----->', size = 16)
plt.ylabel('<-----Number of Apps ----->', size = 16)

plt.show()

# %% [markdown]
# Important Findings:
# *  Most of the apps in Play Store belongs to the category of 'Family'.
# *  And then 'Game' and 'Tools'.

# %%
# NUMBER OF INSTALLS FOR EACH CATEGORY

categories = store_df.groupby('Category')
category_installs_sum_df = categories[['Installs']].sum().reset_index()   # TO CONVERT GROUP BY OBJECTS INTO DATAFRAME

plt.figure(figsize = (10, 5))
sns.barplot(x = 'Category', y = 'Installs', data=category_installs_sum_df)

plt.xticks(rotation = 90)
plt.xlabel('<-----App Category----->', size = 16)
plt.ylabel('<-----Installs (e+10) ----->', size = 16)
plt.title('Number of Installs For Each Category', size = 20)

plt.show()

# %% [markdown]
# Important Findings:
# *  Most of the downloaded and installed apps are from the category of 'Games'.
# *  And then 'Communication' and 'Tools'.

# %% [markdown]
# ## Rating

# %%
# DISTRIBUTION OF RATING

plt.figure(figsize = (11, 5))
sns.countplot(x = 'Rating', data = store_df)

plt.title('Rating Distribution', size = 20)
plt.xticks(rotation = 90)
plt.xlabel('<-----Rating ----->', size = 16)
plt.ylabel('<-----Number of Apps ----->', size = 16)

plt.show()

# %% [markdown]
# Important Findings:
# *  The highest rating is 4.3.
# *  There very few apps (less than 500) are having 5.0 rating.
# *  Most of the apps in the Play Store are having rating higher than 4 or in the range of 4 to 4.7.

# %%
# GRAPHS OF REVIEWS, SIZE, INSTALLS AND PRICE PER RATING

rating_df = store_df.groupby('Rating').sum().reset_index()   # MAKING A DATAFRAME TO PLOT

fig, axes = plt.subplots(1, 4, figsize = (19, 4))

axes[0].plot(rating_df['Rating'], rating_df['Reviews'], 'r')
axes[0].set_xlabel('<-----Rating ----->')
axes[0].set_ylabel('<-----Reviews ----->')
axes[0].set_title('Reviews Per Rating')

axes[1].plot(rating_df['Rating'], rating_df['Size'], 'b')
axes[1].set_xlabel('<-----Rating ----->')
axes[1].set_ylabel('<-----Size ----->')
axes[1].set_title('Size Per Rating')

axes[2].plot(rating_df['Rating'], rating_df['Installs'], 'g')
axes[2].set_xlabel('<-----Rating ----->')
axes[2].set_ylabel('<-----Installs (e+10) ----->')
axes[2].set_title('Installs Per Rating')

axes[3].plot(rating_df['Rating'], rating_df['Price'], 'k')
axes[3].set_xlabel('<-----Rating ----->')
axes[3].set_ylabel('<-----Price ----->')
axes[3].set_title('Price Per Rating')

plt.tight_layout()
plt.show()

# %% [markdown]
# Important Findings:
# *  Most of the apps with higher rating range of 4.0 - 4.7 are having high amount of reviews, size, and installs.
# *  So, users generally prefer apps having higher rating.
# *  In terms of price, it doesn't reflect a direct relationship with rating, as we could see a fluctuation in term of pricing even at the range of high rating.
# *  But, the apps having higher prices have the good rating.

# %% [markdown]
# ##Application Type

# %%
# PERCENTAGE OF TYPE DISTRIBUTION - FREE VS PAID

counts = list(store_df['Type'].value_counts())
labels = 'Free', 'Paid'

matplotlib.rcParams['font.size'] = 12
matplotlib.rcParams['figure.figsize'] = (10, 10)

plt.pie(counts, labels = labels, explode = [0, 0.15], shadow = True, autopct = "%.2f%%")
plt.title('A Pie Chart Representing Percentage of Type Distributions', size = 20)
plt.axis('off')
plt.legend()

plt.show()

# %% [markdown]
# Important Findings:
# *  Most of the apps in Play Store are 'Free'.

# %%
# DISTRIBUTION OF APPS IN TERMS OF THEIR RATING, SIZE AND TYPE

plt.figure(figsize = (14, 8))
sns.scatterplot(store_df['Size'], store_df['Rating'], hue = store_df['Type'], s = 50)

plt.title('Distribution of apps in terms of their Rating, Size and Type', size = 20)
plt.xlabel('<-----Size ----->', size = 16)
plt.ylabel('<-----Rating ----->', size = 16)

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Important Findings:
# *   Most of the free apps are small in size (within 40 MB).
# *   Most of the high rating apps are also smaller in size.

# %%
# CORRELATION

store_df.corr()
# Out:
#             Rating   Reviews      Size  Installs     Price
# Rating    1.000000  0.050209  0.027402  0.034310 -0.018661
# Reviews   0.050209  1.000000  0.037871  0.625164 -0.007599
# Size      0.027402  0.037871  1.000000 -0.007487 -0.015061
# Installs  0.034310  0.625164 -0.007487  1.000000 -0.009406
# Price    -0.018661 -0.007599 -0.015061 -0.009406  1.000000

# %%
# PLOTTING THE CORRELATION

fig, axes = plt.subplots(figsize = (8, 8))
sns.heatmap(store_df.corr(), ax = axes, annot = True, linewidths = 0.1, fmt = '.2f', square = True)

plt.show()

# %% [markdown]
# Important findings
#
# *   The number of installs is greater if reviews are higher
# *   A positive correlation exist between Installs and reviews i.e 0.63

# %% [markdown]
# ## Size

# %%
# PLOTTING A HISTOGRAM - SIZE VS. NUMBER OF APPS INSTALLED

plt.figure(figsize = (11, 9))
plt.hist(store_df['Size'])

plt.title("Distribution of Size", size = 20)
plt.xlabel("<-----Size ----->", size = 16)
plt.ylabel('<-----Number of Apps Installed----->', size = 16)

plt.show()

# %% [markdown]
# Important Findings:
#
# *  Most of the apps in Play store are smaller in size (within 10 MB).

# %% [markdown]
# #User Review DataFrame

# %%
# MERGING WITH store_df

merged_df = store_df.merge(review_df, on = 'App')

# %%
# RANDOM 10 ROWS

merged_df.sample(10)
# Out:
#                                                    App            Category  \
# 19997                       Health and Nutrition Guide  HEALTH_AND_FITNESS
# 29427                   Harry Potter: Hogwarts Mystery                GAME
# 19503                            10 Best Foods for You  HEALTH_AND_FITNESS
# 59347                            Create A Superhero HD              FAMILY
# 48991  Files Go by Google: Free up space on your phone               TOOLS
# 35181                                      Checkers ✔️              FAMILY
# 54977                                    File Explorer        PRODUCTIVITY
# 59479                                       4 in a Row                GAME
# 18741                    Calm - Meditate, Sleep, Relax  HEALTH_AND_FITNESS
# 55150                          ColorNote Notepad Notes        PRODUCTIVITY
#
#        Rating    Reviews       Size     Installs  Type  Price Content Rating  \
# 19997     4.3     7895.0   3.300000     500000.0  Free    0.0       Everyone
# 29427     4.4  1107310.0   0.000000   10000000.0  Free    0.0           Teen
# 19503     4.0     2490.0   3.800000     500000.0  Free    0.0   Everyone 10+
# 59347     3.3     8642.0  19.000000     500000.0  Free    0.0           Teen
# 48991     4.6   315585.0   8.500000   10000000.0  Free    0.0       Everyone
# 35181     4.1     3617.0  19.000000    1000000.0  Free    0.0       Everyone
# 54977     4.1      979.0   0.703125     100000.0  Free    0.0       Everyone
# 59479     3.8     4257.0   0.000000     500000.0  Free    0.0       Everyone
# 18741     4.6   111450.0   0.000000    5000000.0  Free    0.0       Everyone
# 55150     4.6  2401017.0   0.000000  100000000.0  Free    0.0       Everyone
#
#                   Genres        Last Updated         Current Ver  \
# 19997   Health & Fitness       July 15, 2018                 3.3
# 29427          Adventure      August 1, 2018               1.8.2
# 19503   Health & Fitness   February 17, 2017                 1.9
# 59347             Casual   December 30, 2017               4.0.4
# 48991              Tools       July 18, 2018       1.0.204375696
# 35181  Board;Brain Games       July 24, 2018               4.0.2
# 54977       Productivity  September 30, 2013               2.1.3
# 59479              Board        May 13, 2018  Varies with device
# 18741   Health & Fitness      August 5, 2018  Varies with device
# 55150       Productivity       June 27, 2018  Varies with device
#
#               Android Ver                                  Translated_Review  \
# 19997          4.0 and up                                        This good..
# 29427          4.4 and up  I'm Harry Potter fan. I absolutely love game. ...
# 19503        2.3.3 and up                                   Very informative
# 59347          2.3 and up  I've using 3 years I'm pretty sure people made...
# 48991          5.0 and up  I without recommend everyone. Don't killers, h...
# 35181          4.1 and up                  It's simple I need somebody tight
# 54977          2.2 and up                                              K K M
# 59479  Varies with device                                          Excellent
# 18741  Varies with device  Absolutely lobe perfect people like either iss...
# 55150  Varies with device  I loved app. I time. Unfortunately I changed p...
#
#       Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 19997  Positive            0.700000                0.600000
# 29427  Positive            0.173810                0.553571
# 19503  Positive            0.200000                0.300000
# 59347  Positive            0.150000                0.514286
# 48991  Positive            0.266667                0.560000
# 35181  Negative           -0.089286                0.321429
# 54977   Neutral            0.000000                0.000000
# 59479  Positive            0.150000                0.514286
# 18741  Positive            0.450000                0.616667
# 55150  Positive            0.141667                0.550000

# %% [markdown]
# Important Findings:
# * In the merged_df, we found three new columns i.e.. Sentiment, Sentiment Polarity and Sentiment Subjectivity.
# * **Sentiment** basically determines the attitude or the emotion of the writer, i.e., whether it is positive or negative or neutral.
# * **Sentiment Polarity** is float which lies in the range of [-1, 1] where 1 means positive statement and -1 means a negative statement.
# * **Sentiment Subjectivity** generally refer to personal opinion, emotion or judgment, which lies in the range of [0, 1].

# %% [markdown]
# ##Distribution of type of reviews

# %%
# MAKING A NEW DF OF CATEGORY AND SENTIMENT

category_sentiment = merged_df.groupby(['Category', 'Sentiment']).size().reset_index(name = 'Sentiment Count')

# %%
# COUNTING THE SENTIMENTS

category_sentiment['log_sentiment_count'] = np.log2(category_sentiment['Sentiment Count'])

# %%
# PLOTTING THE GRAPH

plt.figure(figsize = (18, 9))
sns.barplot('Category', 'log_sentiment_count', hue='Sentiment', data = category_sentiment)

plt.xticks(rotation = 90)
plt.xlabel("<-----Category ----->", size = 16)
plt.ylabel("<-----Number of Installs ----->", size = 16)
plt.title("Number of installs, type wise, as per Genres", size = 20)

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Important Findings:
#
# *  The maximum number of positive review belongs to the gener 'Game'.
# *  The maximum number of negative review also belongs to the gener 'Game'.
# *  And the maximum number of neutral review belongs to the gener 'Family'.

# %% [markdown]
# ## Percentage of Review Sentiments

# %%
counts = list(merged_df['Sentiment'].value_counts())
labels = 'Positive Reviews', 'Negetive Reviews','Neutral Reviews'

matplotlib.rcParams['font.size'] = 12
matplotlib.rcParams['figure.figsize'] = (10, 10)

plt.pie(counts, labels = labels, explode = [0, 0.05, 0.005], shadow = True, autopct = "%.2f%%")
plt.title('A Pie Chart Representing Percentage of Review Sentiments', size = 20)
plt.axis('off')
plt.legend()

plt.show()

# %% [markdown]
# ##Histogram of Subjectivity

# %%
plt.figure(figsize = (18, 9))
plt.hist(merged_df[merged_df['Sentiment_Subjectivity'].notnull()]['Sentiment_Subjectivity'])

plt.xlabel("<-----Subjectivity ----->", size = 16)
plt.title("Distribution of Subjectivity", size = 20)

plt.show()

# %% [markdown]
# Important Findings:
# * Maximum number of sentiment subjectivity lies between 0.5 to 0.6.
# * From this we can conclude that macimum number of users give reviews to the applications, according to their experience.

# %% [markdown]
# ## Does sentiment_subjectivity proportional to sentiment_polarity?

# %%
# CREATING A DF 

sentimet_subjectivity_polarity = merged_df.groupby(['Category'])['Sentiment_Polarity','Sentiment_Subjectivity'].mean().reset_index().rename\
                                (columns={'Sentiment_Polarity':'Sentiment_polarity_avg','Sentiment_Subjectivity':'sentiment_subjectivity_avg'})
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
merged_df['Sentiment_Subjectivity'] = merged_df['Sentiment_Subjectivity'].abs()

# %%
merged_df['Sentiment_Polarity'] = merged_df['Sentiment_Polarity'].abs()

# %%
plt.figure(figsize=(14,7))
sns.scatterplot(merged_df['Sentiment_Subjectivity'], merged_df['Sentiment_Polarity'])
plt.title("Does sentiment_subjectivity proportional to sentiment_polarity")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Important Findings:
#
# *  Sentiment subjectivity is not always proportional to sentiment polarity.
# *  But in maximum number of cases, it shows a proportional behavior when variance is too high or low.

# %% [markdown]
# # Conclusion

# %% [markdown]
# *  The Google Play Store Apps report provides some useful insights regarding the trending of the apps in the play store. as per the graphs visualizations shown above, most of the trending apps (in terms of users' installs) are from the categories like GAME, COMMUNICATION and TOOL even though the amount of available apps from these categories are twice as much lesser then the category FAMILY. The trending of these apps are most probably due to their nature of being able to entertain or assist the user. Besides, it also shows a good trend where we can see that developers from these categories are focusing on the quality of the apps.
#
# *  Other than that, the charts shown above actually implies that most of the apps having good ratings of above 4.0 are mostly confirmed to have high number of reviews and user installs. There are some spikes in term of size and price but it shouldn't reflect that apps with high rating are mostly big in size and pricy as by looking at the graphs they are most probably are due to some minority. Furthermore, most of the apps that are having high number of reviews are from the categories of SOCIAL, COMMUNICATION and GAME like Facebook, WhatsApp Messenger, Instagram, Messenger – Text and Video Chat for Free, Clash of Clans etc.
#
# *  Even though apps from the categories like GAME, SOCIAL, COMMUNICATION and TOOL of having the highest number of installs, rating and reviews are reflecting the current trend of Android users, they are not even appearing as category in the top 5 most expensive apps in the store (which are mostly from FINANCE and LIFESTYLE). As a conclusion, we learnt that the current trend in the Android market is mostly from these categories which either assisting, communicating or entertaining apps.
